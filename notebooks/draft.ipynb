# %%
import pandas as pd
from typing import List

# %%
# this is to simulate calling a script from cli with arguments
ARGS: List[str] = ['', '1']

# %%
day: int = int(ARGS[1])
print(f"Running pipeline for day {day}")
# Out:
# Running pipeline for day 1

# %%
df = pd.DataFrame({"A": [1, 2]})
df.head()
# Out:
#    A
# 0  1
# 1  2

# %%
df.to_parquet(f"output_day_{day}.parquet")
